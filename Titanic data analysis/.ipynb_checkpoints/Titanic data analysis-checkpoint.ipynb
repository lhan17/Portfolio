# %% [markdown]
# # Data analysis on Titanic dataset

# %% [markdown]
# ## Titanic: data preprocessing and imputation

# %% [markdown]
# Data is downloaded from [Titanic dataset](https://www.kaggle.com/c/titanic) from Kaggle.
#
# The dataset consists of personal information of all the passengers on board the Titanic, along with the information whether they survived the iceberg collision or not.

# %%
# Imports
import numpy as np
import pandas as pd

# Reading csv data
titanic = pd.read_csv('train.csv')
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# ![](vari.png)

# %% [markdown]
# Above picture is from Kaggle

# %%
# Removing unnecessary columns
titanic = titanic.drop(columns = ['Name', 'PassengerId', 'Ticket'])
titanic.shape
# Out:
# (891, 9)

# %%
titanic
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
# Taking Cabin's first letter and making it the Deck. 
# Those without a letter shall be NaN. Then removing Cabin because it is an unnecessary column.
titanic["Deck"] = titanic["Cabin"].str[0]
titanic = titanic.drop("Cabin", axis = 1)
titanic.head(100)
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked Deck
# 0          0       3    male  22.0      1      0   7.2500        S  NaN
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# ..       ...     ...     ...   ...    ...    ...      ...      ...  ...
# 95         0       3    male   NaN      0      0   8.0500        S  NaN
# 96         0       1    male  71.0      0      0  34.6542        C    A
# 97         1       1    male  23.0      0      1  63.3583        C    D
# 98         1       2  female  34.0      0      1  23.0000        S  NaN
# 99         0       2    male  34.0      1      0  26.0000        S  NaN
#
# [100 rows x 9 columns]

# %%
# Now we transform categorical values to numerical values
categorical_values = ["Sex", "Embarked", "Deck"]

for val in categorical_values:
    titanic[val] = titanic[val].astype('category')

cat_columns = titanic.select_dtypes(['category']).columns
titanic[cat_columns] = titanic[cat_columns].apply(lambda x: x.cat.codes)

titanic.replace(-1, np.NaN, inplace=True)

titanic.head(5)
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Deck
# 0         0       3    1  22.0      1      0   7.2500       2.0   NaN
# 1         1       1    0  38.0      1      0  71.2833       0.0   2.0
# 2         1       3    0  26.0      0      0   7.9250       2.0   NaN
# 3         1       1    0  35.0      1      0  53.1000       2.0   2.0
# 4         0       3    1  35.0      0      0   8.0500       2.0   NaN

# %% [markdown]
# ## Imputation
# Machine learning algorithms have problems with missing values so I'll fill them with multivariate imputer that estimates each feature from all the others. The imputer is from fancyimpute package and it's a strategy for imputing missing balues by modeling each feature with missing values as a function of other features in a round-robin fashion. This is not the best way to fill missing values, but if we take all the N/A values out of data we risk losing useful information.

# %%
from fancyimpute import IterativeImputer 

mice_imputer = IterativeImputer()
imputed_titanic = mice_imputer.fit_transform(titanic)

# %%
# age, deck, embarked, sex, parch categories that are not double.
titanic = pd.DataFrame(imputed_titanic, columns=titanic.columns)
titanic['Age'] = titanic['Age'].round()
titanic['Deck'] = titanic['Deck'].round()
titanic['Embarked'] = titanic['Embarked'].round()
titanic['Sex'] = titanic['Sex'].round()
titanic['Parch'] = titanic['Parch'].round()

print(titanic)
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Deck
# 0         0.0     3.0  1.0  22.0    1.0    0.0   7.2500       2.0   5.0
# 1         1.0     1.0  0.0  38.0    1.0    0.0  71.2833       0.0   2.0
# 2         1.0     3.0  0.0  26.0    0.0    0.0   7.9250       2.0   5.0
# 3         1.0     1.0  0.0  35.0    1.0    0.0  53.1000       2.0   2.0
# 4         0.0     3.0  1.0  35.0    0.0    0.0   8.0500       2.0   5.0
# ..        ...     ...  ...   ...    ...    ...      ...       ...   ...
# 886       0.0     2.0  1.0  27.0    0.0    0.0  13.0000       2.0   4.0
# 887       1.0     1.0  0.0  19.0    0.0    0.0  30.0000       2.0   1.0
# 888       0.0     3.0  0.0  23.0    1.0    2.0  23.4500       2.0   5.0
# 889       1.0     1.0  1.0  26.0    0.0    0.0  30.0000       0.0   2.0
# 890       0.0     3.0  1.0  32.0    0.0    0.0   7.7500       1.0   5.0
#
# [891 rows x 9 columns]

# %%
titanic.head(10)
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Deck
# 0       0.0     3.0  1.0  22.0    1.0    0.0   7.2500       2.0   5.0
# 1       1.0     1.0  0.0  38.0    1.0    0.0  71.2833       0.0   2.0
# 2       1.0     3.0  0.0  26.0    0.0    0.0   7.9250       2.0   5.0
# 3       1.0     1.0  0.0  35.0    1.0    0.0  53.1000       2.0   2.0
# 4       0.0     3.0  1.0  35.0    0.0    0.0   8.0500       2.0   5.0
# 5       0.0     3.0  1.0  29.0    0.0    0.0   8.4583       1.0   5.0
# 6       0.0     1.0  1.0  54.0    0.0    0.0  51.8625       2.0   4.0
# 7       0.0     3.0  1.0   2.0    3.0    1.0  21.0750       2.0   6.0
# 8       1.0     3.0  0.0  27.0    0.0    2.0  11.1333       2.0   5.0
# 9       1.0     2.0  0.0  14.0    1.0    0.0  30.0708       0.0   4.0

# %%
titanic.to_csv('titanic.csv')
titanic.to_json('titanic.json', orient = 'table')

# %% [markdown]
# We should be very careful when choosing to impute missing data. Sometimes it can make big changes to the outcome of the analysis.

# %% [markdown]
# ## Exploratory data analysis
#
# Now we will study the cleaned data above with exploratory data analysis.

# %%
print(titanic.columns)
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked', 'Deck'],
#       dtype='object')

# %%
femalecount = titanic[titanic["Sex"] == 0].count()[0]
malecount = titanic[titanic["Sex"] == 1].count()[0]
survcount = titanic[titanic["Survived"]== 1].count()[0]
nonsurvcount = titanic[titanic["Survived"]== 0].count()[0]

# %%
from matplotlib import pyplot as plt
fig, (axs1, axs2) = plt.subplots(1,2)
axs1.pie([femalecount, malecount], labels = ['Female', 'Male'],autopct='%1.2f%%');
axs2.pie([survcount, nonsurvcount], labels = ['Survived', 'Did not survive'],autopct='%1.2f%%');

# %%
import statistics as st
# medians of continous variables and modes of categorical variables to make an average human on board.
mSurvived = st.mode(titanic['Survived'])
mPclass = st.mode(titanic['Pclass'])
mSex = st.mode(titanic['Sex'])
mAge = np.mean(titanic['Age'])
mSibSp = np.mean(titanic['SibSp'])
mParch = np.mean(titanic['Parch'])
mFare = np.mean(titanic['Fare'])
mEmbarked = st.mode(titanic['Embarked'])
mDeck = st.mode(titanic['Deck'])

average = [mSurvived, mPclass, mSex, mAge, mSibSp, mParch, mFare,
       mEmbarked, mDeck]
ave = pd.DataFrame(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare','Embarked', 'Deck'], [average])
print("Average person on board: ", ave)
# 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare','Embarked', 'Deck'
# Out:
# Average person on board:                    0
# 0.000000   Survived
# 3.000000     Pclass
# 1.000000        Sex
# 29.278339       Age
# 0.523008      SibSp
# 0.381594      Parch
# 32.204208      Fare
# 2.000000   Embarked
# 5.000000       Deck

# %%
# average survivor/non-survivor

aPclass = st.mode(titanic[titanic['Survived'] == 1]['Pclass'])
aSex = st.mode(titanic[titanic['Survived'] == 1]['Sex'])
aAge = np.mean(titanic[titanic['Survived'] == 1]['Age'])
aSibSp = np.mean(titanic[titanic['Survived'] == 1]['SibSp'])
aParch = np.mean(titanic[titanic['Survived'] == 1]['Parch'])
aFare = np.mean(titanic[titanic['Survived'] == 1]['Fare'])
aEmbarked = st.mode(titanic[titanic['Survived'] == 1]['Embarked'])
aDeck = st.mode(titanic[titanic['Survived'] == 1]['Deck'])
avg_surv = [aPclass, aSex, aAge, aSibSp, aParch, aFare,
       aEmbarked, aDeck]

nPclass = st.mode(titanic[titanic['Survived'] == 0]['Pclass'])
nSex = st.mode(titanic[titanic['Survived'] == 0]['Sex'])
nAge = np.mean(titanic[titanic['Survived'] == 0]['Age'])
nSibSp = np.mean(titanic[titanic['Survived'] == 0]['SibSp'])
nParch = np.mean(titanic[titanic['Survived'] == 0]['Parch'])
nFare = np.mean(titanic[titanic['Survived'] == 0]['Fare'])
nEmbarked = st.mode(titanic[titanic['Survived'] == 0]['Embarked'])
nDeck = st.mode(titanic[titanic['Survived'] == 0]['Deck'])
avg_nonsurv = [nPclass, nSex, nAge, nSibSp, nParch, nFare,
    nEmbarked, nDeck]

# %%
avgsu = pd.DataFrame(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare','Embarked', 'Deck'], [avg_surv])
avgnsu = pd.DataFrame(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare','Embarked', 'Deck'], [avg_nonsurv])

print("Average survivor: ", avgsu)
print("Average non-survivor: ", avgnsu)
# 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare','Embarked', 'Deck'
# Out:
# Average survivor:                    0
# 1.000000     Pclass
# 0.000000        Sex
# 27.929825       Age
# 0.473684      SibSp
# 0.464912      Parch
# 48.395408      Fare
# 2.000000   Embarked
# 5.000000       Deck
# Average non-survivor:                    0
# 3.000000     Pclass
# 1.000000        Sex
# 30.118397       Age
# 0.553734      SibSp
# 0.329690      Parch
# 22.117887      Fare
# 2.000000   Embarked
# 5.000000       Deck

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('Age')
ax.set_ylabel('Fare')


plt.axvspan(76, 76, facecolor='g', alpha=1)
plt.annotate('Average survivor', xy=(avg_surv[2], avg_surv[5]), xytext=(105,70),
xycoords='data',textcoords='offset points',arrowprops=dict(arrowstyle="-"))

plt.annotate('Average non-survivor', xy=(avg_nonsurv[2], avg_nonsurv[5]), xytext=(125, 50),
xycoords='data',textcoords='offset points',arrowprops=dict(arrowstyle="-"))

surv = titanic[titanic["Survived"] == 1]
non_surv = titanic[titanic["Survived"] == 0]

plt.scatter(surv['Age'], surv['Fare'], s=13, marker='o', c='blue', lw=0, alpha=0.7, label='Survivors')
plt.scatter(non_surv['Age'], non_surv['Fare'], s=13, marker='o', c='violet', lw=0, alpha=0.7, label = 'Non-survivors')
plt.scatter(avg_surv[2], avg_surv[5], s=40, marker='o', c='k', lw=0)
plt.scatter(avg_nonsurv[2], avg_nonsurv[5], s=40, marker='o', c='k', lw=0)
plt.title("Comparison between fare and age")
plt.legend(loc="upper right")
plt.xlim((0,75))
plt.ylim((0,300))
plt.show()

# %%
import seaborn as sns
titaniccopy = titanic.copy()
titaniccopy["Survived"] = titaniccopy["Survived"].replace([0],"Non-survivor")
titaniccopy["Survived"] = titaniccopy["Survived"].replace([1],"Survivor")
plot = sns.pairplot(titaniccopy[['Survived','Age', 'Fare']], hue = "Survived", palette = ["violet","blue"], diag_kind = "kde", height = 10)
plot.fig.suptitle("Age and fare variables in pairplot, hue = Survived", y = 1.08,fontsize=50)
# with diag_kind = kde parameter we get smoothened histogram plot
# Out:
# Text(0.5, 1.08, 'Age and fare variables in pairplot, hue = Survived')

# %%
titaniccopy = titanic.copy()
titaniccopy["Sex"] = titaniccopy["Sex"].replace([0],"Female")
titaniccopy["Sex"] = titaniccopy["Sex"].replace([1],"Male")
plot = sns.pairplot(titaniccopy[['Sex','Age', 'Fare']], hue = "Sex", palette = ["blue", "violet"], diag_kind = "kde", height = 10)
plot.fig.suptitle("Age and fare variables in pairplot, hue = Sex", y = 1.08, fontsize = 50)
# Out:
# Text(0.5, 1.08, 'Age and fare variables in pairplot, hue = Sex')

# %%
# Now we visualize categorical variables.
def visualize_cat(x):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.set_xlabel(x)
    
    ax.set_ylabel('Passenger Count')

    tb = pd.pivot_table(data=titanic, values='Age', index=x, columns='Survived', aggfunc='count')
    bar1=tb[0]
    bar2=tb[1]
    
    i = np.arange(len(bar1))
    firstb = plt.bar(i, bar1, 0.5, color='b', label = 'Non-survivors')
    secondb = plt.bar(i, bar2, 0.5, color='y', bottom=bar1, label = 'Survivors')

    plt.title('Passenger count per ' + x)
    plt.legend(loc = 'upper center')
    plt.show()

# 0 (left) is male and 1 (right) is female
visualize_cat('Sex')
visualize_cat('Deck')
visualize_cat('Pclass')
visualize_cat('Embarked')
visualize_cat('SibSp')
visualize_cat('Parch')

# %% [markdown]
# ### Insights from above histograms
# - There are less women but more women survivors
# - Most survivor come from deck F (2)
# - There are most survivors from first class (0). Althought there are a lot more third class people on board.
# - (0 = Cherbourg, 1 = Queenstown, 2 = Southampton) Most people boarded from Southampton.
# - Sibsp and parch seems pretty normal. Most people came on board without children, siblings, spouses or parents.

# %%
titanic.corr()
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.338481 -0.543351 -0.077698 -0.035322  0.081629
# Pclass   -0.338481  1.000000  0.131900 -0.407159  0.083081  0.018443
# Sex      -0.543351  0.131900  1.000000  0.117206 -0.114631 -0.245489
# Age      -0.077698 -0.407159  0.117206  1.000000 -0.379183 -0.219842
# SibSp    -0.035322  0.083081 -0.114631 -0.379183  1.000000  0.414838
# Parch     0.081629  0.018443 -0.245489 -0.219842  0.414838  1.000000
# Fare      0.257307 -0.549500 -0.182333  0.092946  0.159651  0.216225
# Embarked -0.171249  0.166521  0.112094 -0.020969  0.069568  0.041137
# Deck     -0.294726  0.886776  0.078201 -0.424752  0.241623  0.079859
#
#               Fare  Embarked      Deck
# Survived  0.257307 -0.171249 -0.294726
# Pclass   -0.549500  0.166521  0.886776
# Sex      -0.182333  0.112094  0.078201
# Age       0.092946 -0.020969 -0.424752
# SibSp     0.159651  0.069568  0.241623
# ...

# %%
plt.figure(figsize=(25,8))
heatmap = sns.heatmap(titanic.corr(),annot= True)
heatmap.set_title('Correlation Heatmap');

# %% [markdown]
# ### Insights from Heatmap
# - There is -0.55 negative correlation in between Fare and Pclass.
# - High -0.54 negative correlation between Sex and Survived. We can see from above histograms that over 50 percent of women survived.
# - There is high 0.41 positive correlation between Sibsp and Parch. If someone has children on board there is a high possibility that their spouse are with them.
# - There is -0.34 negative correlation between Pclass and Survived. So a little higher survivability chance in what class you belong.
# - There is -0.33 negative correlation between Age and Pclass.

# %% [markdown]
# ## Supervised Machine Learning models and their accuracy

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor

# %%
titanic.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Deck
# 0       0.0     3.0  1.0  22.0    1.0    0.0   7.2500       2.0   5.0
# 1       1.0     1.0  0.0  38.0    1.0    0.0  71.2833       0.0   2.0
# 2       1.0     3.0  0.0  26.0    0.0    0.0   7.9250       2.0   5.0
# 3       1.0     1.0  0.0  35.0    1.0    0.0  53.1000       2.0   2.0
# 4       0.0     3.0  1.0  35.0    0.0    0.0   8.0500       2.0   5.0

# %%
# 80/20 train test split
# titanic.shape, 891/100*80,891/100*20

# %% [markdown]
# ### Logistic regression
# Logistic regression, also recognized as maximum-entropy classification (MaxEnt), logit regression, or the log-linear classifier, is a statistical method utilized for classification tasks, particularly in scenarios involving binary outcomes. This model operates within the framework of linear regression but employs the logistic function to accommodate the classification nature of the problem.
#
# In essence, logistic regression assesses the relationship between a set of independent variables and a binary dependent variable, assigning probabilities to the occurrence of each class within the binary outcome. These probabilities are then transformed using the logistic function, which maps them onto a bounded range between 0 and 1, facilitating the interpretation of the results as probabilities.
#
# A key advantage of logistic regression lies in its simplicity and interpretability, making it a popular choice for various applications, including predictive modeling and risk assessment. By estimating the coefficients associated with each independent variable, logistic regression provides insights into the impact of different features on the likelihood of a particular outcome.
#
# In the context of survivor prediction, logistic regression can be utilized to distinguish between survivors and non-survivors based on relevant predictor variables. By fitting a logistic regression model to the available data, one can estimate the likelihood of survival for each individual, thereby enabling informed decision-making in scenarios such as medical prognosis or risk assessment.
#
# Despite its simplicity, logistic regression offers considerable flexibility and can be extended to accommodate more complex relationships through techniques such as polynomial regression or regularization methods. Moreover, logistic regression is robust to noise and outliers, provided that the underlying assumptions of the model are met.
#
# Overall, logistic regression serves as a versatile and reliable tool for binary classification tasks, offering a balance between interpretability and predictive performance. Its application extends across various domains, from healthcare and finance to marketing and social sciences, where the accurate classification of binary outcomes is of paramount importance.

# %%
# Prepare data for models.
# Splitting the Titanic data 80/20 train test
x_train = titanic.drop(labels = "Survived", axis = 1)[0:712]
y_train = titanic["Survived"][0:712]
x_test = titanic.drop("Survived", axis = 1)[713:890]

# %%
#Logistic regression
logr = LogisticRegression( max_iter=1000)
logr.fit(x_train, y_train)
y_pred = logr.predict(x_test)
accuracy_logr = round(logr.score(x_train, y_train) * 100, 2)
accuracy_logr
# Out:
# 81.04

# %% [markdown]
# ## Logistic Lasso
#
# Logistic Lasso, a variant of logistic regression, introduces a regularization term known as the Lasso (Least Absolute Shrinkage and Selection Operator) penalty into the regression framework. This regularization term is instrumental in addressing issues such as overfitting and feature selection, making Logistic Lasso particularly effective in scenarios where there are a large number of predictor variables.
#
# The inclusion of the Lasso penalty in Logistic Lasso encourages sparsity in the coefficient estimates by penalizing the absolute magnitude of the coefficients. This regularization technique imposes constraints on the model parameters during the optimization process, effectively shrinking less important coefficients towards zero. Consequently, irrelevant or redundant features are either assigned negligible coefficients or entirely eliminated from the model, leading to a more parsimonious representation and enhancing the model's interpretability.
#
# By incorporating the Lasso penalty, Logistic Lasso promotes feature selection, automatically identifying and retaining the most influential predictors while discarding those with minimal impact on the outcome. This not only simplifies the model but also improves its generalization performance by reducing the risk of overfitting to noisy or irrelevant variables.
#
# In practice, the strength of the regularization in Logistic Lasso is controlled by a tuning parameter, often denoted as λ (lambda), which governs the balance between the goodness of fit and the complexity of the model. By adjusting the value of λ, practitioners can fine-tune the trade-off between sparsity and predictive accuracy, tailoring the model to suit the specific requirements of the task at hand.
#
# Logistic Lasso finds applications in various fields, including biomedical research, finance, and marketing, where the identification of relevant features and the construction of interpretable models are essential. By harnessing the power of regularization, Logistic Lasso offers a robust framework for binary classification tasks, capable of delivering accurate predictions while facilitating insights into the underlying factors driving the outcomes of interest.

# %%
log = LogisticRegression(penalty='l1', solver='liblinear')
log.fit(x_train, y_train)
y_pred = log.predict(x_test)
accuracy_log = round(log.score(x_train, y_train) * 100, 2)
accuracy_log
# Out:
# 80.48

# %% [markdown]
# ### Support Vector Machine
# Support Vector Machine (SVM) is a versatile set of machine learning algorithms used for classification and regression tasks. In the Titanic dataset, SVM constructs a maximum-margin hyperplane to effectively classify survivors and non-survivors.
#
# SVM aims to find the hyperplane with the largest margin between classes, enhancing robustness and generalization. It utilizes support vectors, data points nearest to the decision boundary, for optimal separation.
#
# SVM can handle nonlinear relationships using different kernels:
#
# Linear Kernel: Draws straight lines for linearly separable data.
#
# Radial Basis Function (RBF) Kernel: Uses curved lines to capture nonlinear patterns.
#
# Polynomial Kernel: Introduces polynomial decision boundaries for complex relationships.
#
# By selecting the appropriate kernel and tuning parameters, SVM provides accurate classification in the Titanic dataset, offering insights into survival factors.

# %%
# SVM linear kernel
svc = SVC(kernel = "linear")
svc.fit(x_train, y_train)
y_pred = svc.predict(x_test)
accuracy_svc1 = round(svc.score(x_train, y_train)*100,2)
accuracy_svc1
#The best out of three kernels
# Out:
# 78.37

# %%
# SVM rbf kernel
svc = SVC(kernel = "rbf")
svc.fit(x_train, y_train)
y_pred = svc.predict(x_test)
accuracy_svc2 = round(svc.score(x_train, y_train)*100,2)
accuracy_svc2
# Out:
# 68.4

# %%
# SVM polynomial kernel 
svc = SVC(kernel = "poly")
svc.fit(x_train, y_train)
y_pred = svc.predict(x_test)
accuracy_svc3 = round(svc.score(x_train, y_train)*100,2)
accuracy_svc3
# Out:
# 63.76

# %% [markdown]
# ### k-Nearest Neighbor (k-NN)
# k-Nearest Neighbor (k-NN) is a simple yet effective algorithm used in unsupervised learning and pattern recognition. In k-NN, a point is classified based on its nearest neighbors.
#
# Here's how it works:
# - If \( k = 1 \), the point is classified as the label of its nearest neighbor.
# - For larger \( k \), the point's classification is determined by the majority label among its \( k \) nearest neighbors.
#
# This approach makes k-NN straightforward to implement and understand. It's particularly useful when the decision boundary is complex or not easily characterized by a simple model.
#
# In practical applications, the choice of \( k \) is crucial. Smaller \( k \) values may lead to overfitting, while larger \( k \) values can smooth out decision boundaries but may also introduce bias.
#
# Overall, k-NN is a versatile algorithm with applications ranging from image recognition to recommendation systems. Its simplicity and effectiveness make it a popular choice in various machine learning tasks.

# %%
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
accuracy_knn = round(knn.score(x_train, y_train)*100,2)
accuracy_knn
# Out:
# 80.9

# %% [markdown]
# ## Naive Bayes Classifier
# Naive Bayes is a powerful probabilistic supervised learning algorithm for classification tasks. It utilizes Bayes' theorem with a strong assumption of feature independence (x_train or x_test), simplifying computation, and ensuring efficiency, even with large datasets.
#
# The Gaussian Naive Bayes variant, which we employ below, assumes features follow a normal (Gaussian) distribution. This enables the algorithm to model the probability density function of each feature within Bayes' theorem, facilitating informed classification decisions.
#
# Naive Bayes excels in scenarios with simple, independent feature relationships. Despite its simplistic assumptions, it often performs well, especially when features are conditionally independent given the class label.
#
# Moreover, Naive Bayes classifiers are known for their interpretability, ease of implementation, and robustness to noisy data. This versatility makes them suitable for various applications, including text classification, spam filtering, medical diagnosis, and sentiment analysis.
#
# In essence, the Naive Bayes classifier offers a simple yet effective approach to classification tasks, leveraging probabilistic principles and strong independence assumptions to deliver reliable results across diverse domains.

# %%
gaus = GaussianNB()
gaus.fit(x_train, y_train)
y_pred = gaus.predict(x_test)
accuracy_gaus = round(gaus.score(x_train, y_train)*100,2)
accuracy_gaus
# Out:
# 78.23

# %% [markdown]
# ### Stochastic Gradient Descent
# Stochastic Gradient Descent (SGD) is primarily an optimization method used for training models under convex loss functions. In essence, it's a technique to iteratively update model parameters to minimize the loss function, thereby improving model performance.
#
# When we use SGDClassifier, we're actually employing SVM (Support Vector Machine) as the underlying model. SGDClassifier optimizes the SVM model by iteratively adjusting its parameters to find the optimal hyperplane that maximizes the margin between classes.
#
# SGD is particularly useful in scenarios with large datasets or when training deep learning models, as it updates parameters based on a single data point or a small batch at a time, rather than the entire dataset. This stochastic nature makes SGD highly efficient and scalable.
#
# Overall, Stochastic Gradient Descent serves as a fundamental optimization method, enabling efficient training of complex models like SVM under convex loss functions, ultimately enhancing their predictive capabilities.

# %%
sgd = SGDClassifier()
sgd.fit(x_train, y_train)
y_pred = sgd.predict(x_test)
accuracy_sgd = round(sgd.score(x_train, y_train)*100,2)
accuracy_sgd
# Out:
# 41.29

# %% [markdown]
# ## Decision Tree
# A Decision Tree is a versatile classification algorithm resembling a "flowchart," where nodes represent features and branches represent decisions based on those features. At each node, samples are split based on conditions or probabilities, ultimately classifying them, such as the "Survived" variable in our case.
#
# Below, we experiment with three types of decision tree classifiers:
#
# CART (Classification and Regression Tree): Splits data into subsets based on the best feature and threshold, iteratively refining until homogeneous subsets or a stopping criterion is reached.
#
# Random Forest: An ensemble method combining multiple decision trees, trained on random feature subsets and bootstrap samples, reducing overfitting and improving predictive performance.
#
# Gradient Boosting Decision Trees: Constructs an ensemble of weak learners sequentially, optimizing each tree to correct errors of previous ones, achieving superior performance at the cost of increased complexity.
#
# By exploring these classifiers, we gain insights into their strengths and weaknesses, aiding informed choices based on dataset characteristics and task requirements.

# %%
decision_tree = DecisionTreeClassifier(criterion="gini")
decision_tree.fit(x_train, y_train)
y_pred = decision_tree.predict(x_test)
accuracy_decision_tree = round(decision_tree.score(x_train, y_train)*100,2)
accuracy_decision_tree
# We see that 98.46 is too accurate and I think it is overfitting. So I'll drop this from the comparison.
# Out:
# 98.6

# %%
random_forest = RandomForestClassifier()
random_forest.fit(x_train, y_train)
y_pred = random_forest.predict(x_test)
accuracy_random_forest = round(random_forest.score(x_train, y_train)*100,2)
accuracy_random_forest
# We see that 98.46 is too accurate and I think it is overfitting. So I'll drop this from the comparison.
# Out:
# 98.6

# %%
decision_tree_regressor = DecisionTreeRegressor(criterion="poisson")
decision_tree_regressor.fit(x_train, y_train)
y_pred = decision_tree_regressor.predict(x_test)
accuracy_decision_tree_regressor = round(decision_tree_regressor.score(x_train, y_train)*100,2)
accuracy_decision_tree_regressor
# Out:
# 75.21

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'k-Nearest Neighbor', 'Logistic Regression', 'Naive Bayes', 
              'Stochastic Gradient Decent', 
              'Decision Tree Regressor'],
    'Score': [accuracy_svc1, accuracy_knn,accuracy_logr,accuracy_gaus
              ,accuracy_sgd,accuracy_decision_tree_regressor]})
models.sort_values(by = "Score", ascending=False)
# Out:
#                         Model  Score
# 2         Logistic Regression  81.04
# 1          k-Nearest Neighbor  80.90
# 0     Support Vector Machines  78.37
# 3                 Naive Bayes  78.23
# 5     Decision Tree Regressor  75.21
# 4  Stochastic Gradient Decent  41.29

# %% [markdown]
# ## Result from model comparison
# In conclusion the best accuracy is from logistic regression.

# %% [markdown]
# # Preparing the test data for the Kaggle competition

# %%
import numpy as np
import pandas as pd

# Reading csv data
test = pd.read_csv('test.csv')
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test = test.drop(columns = ['Name', 'Ticket'])
test["Deck"] = test["Cabin"].str[0]
test = test.drop("Cabin", axis = 1)

categorical_values = ["Sex", "Embarked", "Deck"]

for val in categorical_values:
    test[val] = test[val].astype('category')

cat_columns = test.select_dtypes(['category']).columns
test[cat_columns] = test[cat_columns].apply(lambda x: x.cat.codes)

test.replace(-1, np.NaN, inplace=True)

from fancyimpute import IterativeImputer 

# Using IterativeImputer from fancyimpute to fill in missing values.
mice_imputer = IterativeImputer()
imputed_titanic = mice_imputer.fit_transform(test)

test = pd.DataFrame(imputed_titanic, columns=test.columns)
for val in ['Age', 'Deck', 'Embarked', 'Sex', 'Parch']:
    test[val] = test[val].round()

# # Continuous variables imputation
# for val in ["Age", "Fare", "Pclass", "SibSp"]:
#     test[val].fillna(test[val].mean(), inplace=True)

# # Categorical variables imputation
# for val in categorical_values:
#     test[val].fillna(test[val].median(), inplace=True)

# %%
testid = test['PassengerId']
test = test.drop(columns = ['PassengerId'])
test
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked  Deck
# 0       3.0  1.0  34.0    0.0    0.0    7.8292       1.0   5.0
# 1       3.0  0.0  47.0    1.0    0.0    7.0000       2.0   5.0
# 2       2.0  1.0  62.0    0.0    0.0    9.6875       1.0   3.0
# 3       3.0  1.0  27.0    0.0    0.0    8.6625       2.0   5.0
# 4       3.0  0.0  22.0    1.0    1.0   12.2875       2.0   5.0
# ..      ...  ...   ...    ...    ...       ...       ...   ...
# 413     3.0  1.0  24.0    0.0    0.0    8.0500       2.0   5.0
# 414     1.0  0.0  39.0    0.0    0.0  108.9000       0.0   2.0
# 415     3.0  1.0  38.0    0.0    0.0    7.2500       2.0   5.0
# 416     3.0  1.0  24.0    0.0    0.0    8.0500       2.0   5.0
# 417     3.0  1.0  22.0    1.0    1.0   22.3583       0.0   5.0
#
# [418 rows x 8 columns]

# %%
y_pred = logr.predict(test)

# %%
pred = {'PassengerId': testid,'Survived': y_pred}
prediction = pd.DataFrame(pred)
prediction
# Out:
#      PassengerId  Survived
# 0          892.0       0.0
# 1          893.0       0.0
# 2          894.0       0.0
# 3          895.0       0.0
# 4          896.0       1.0
# ..           ...       ...
# 413       1305.0       0.0
# 414       1306.0       1.0
# 415       1307.0       0.0
# 416       1308.0       0.0
# 417       1309.0       0.0
#
# [418 rows x 2 columns]

# %%
prediction = prediction.astype('int32')

# %%
print(prediction.to_csv(index = False))
prediction.to_csv('submission.csv',index = False)
# Out:
# PassengerId,Survived
# 892,0
# 893,0
# 894,0
# 895,0
# 896,1
# 897,0
# 898,1
# 899,0
# 900,1
# 901,0
# 902,0
# 903,0
# 904,1
# 905,0
# 906,1
# 907,1
# 908,0
# 909,0
# 910,1
# 911,0
# 912,0
# 913,0
# 914,1
# 915,1
# 916,1
# 917,0
# 918,1
# 919,0
# 920,0
# 921,0
# 922,0
# 923,0
# 924,0
# 925,1
# 926,1
# 927,0
# 928,1
# 929,1
# 930,0
# 931,0
# 932,0
# 933,0
# 934,0
# 935,1
# 936,1
# 937,0
# 938,0
# 939,0
# 940,1
# 941,0
# 942,1
# 943,0
# 944,1
# 945,1
# 946,0
# 947,0
# 948,0
# 949,0
# 950,0
# 951,1
# 952,0
# 953,0
# 954,0
# 955,1
# 956,1
# 957,1
# 958,1
# 959,0
# 960,1
# 961,1
# 962,1
# 963,0
# 964,1
# 965,1
# 966,1
# 967,1
# 968,0
# 969,1
# 970,0
# 971,1
# 972,0
# 973,0
# 974,0
# 975,0
# 976,0
# 977,0
# 978,1
# 979,1
# 980,1
# 981,0
# 982,1
# 983,0
# 984,1
# 985,0
# 986,1
# 987,0
# 988,1
# 989,0
# 990,1
# 991,0
# 992,1
# 993,0
# 994,0
# 995,0
# 996,1
# 997,0
# 998,0
# 999,0
# 1000,0
# 1001,0
# 1002,0
# 1003,1
# 1004,1
# 1005,1
# 1006,1
# 1007,0
# 1008,0
# 1009,1
# 1010,1
# 1011,1
# ...

# %%
pd.read_csv('submission.csv')
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
